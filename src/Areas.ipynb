# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
# %matplotlib inline

# %%
base = pd.read_csv('../bases/area.csv')

# %%
base['Área'].unique()
# Out:
# array(['Biologia', 'Ciências', 'Interdisciplinar', 'Física', 'Química',
#        'Não menciona'], dtype=object)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x = 'Área', data=base, hue='Ano')
plt.ylabel('Número de publicações')
# Out:
# Text(0, 0.5, 'Número de publicações')

# %%
base.groupby(['Área','Ano'])[['Ano']].count()
# Out:
#                        Ano
# Área             Ano
# Biologia         2004    3
#                  2006    1
#                  2008    5
#                  2010    1
#                  2012    3
#                  2014    9
#                  2018    4
# Ciências         2004    7
#                  2006    3
#                  2008    2
#                  2010   10
#                  2012    4
#                  2016    4
#                  2018    4
# Física           2004    6
#                  2006    4
#                  2008    4
#                  2010    1
#                  2012    9
#                  2014    3
#                  2016    1
# Interdisciplinar 2004    6
#                  2006    3
#                  2008    6
#                  2010    2
#                  2012    4
#                  2014    1
# Não menciona     2006    1
#                  2010    1
#                  2012    2
#                  2016    1
#                  2018    1
# Química          2004    3
#                  2006    2
#                  2008    9
#                  2010    5
#                  2012    4
#                  2014    8
#                  2016    2
#                  2018    1

# %%
plt.figure(figsize=(10,5))
sns.countplot(x = 'Ano', data=base, hue='Área')
plt.ylabel('Número de publicações')
# Out:
# Text(0, 0.5, 'Número de publicações')

# %%
plt.figure(figsize=(10,3))
sns.countplot(x = 'Ano', data=base, hue='Área')
plt.legend(labels=['Biologia','Ciências','Interdisciplinar','Física','Química','Não menciona'], loc=2, bbox_to_anchor=(1,1))
plt.ylabel('Número de publicações')
# Out:
# Text(0, 0.5, 'Número de publicações')

# %%
base.groupby(['Ano','Área',])[['Área']].count()
# Out:
#                        Área
# Ano  Área
# 2004 Biologia             3
#      Ciências             7
#      Física               6
#      Interdisciplinar     6
#      Química              3
# 2006 Biologia             1
#      Ciências             3
#      Física               4
#      Interdisciplinar     3
#      Não menciona         1
#      Química              2
# 2008 Biologia             5
#      Ciências             2
#      Física               4
#      Interdisciplinar     6
#      Química              9
# 2010 Biologia             1
#      Ciências            10
#      Física               1
#      Interdisciplinar     2
#      Não menciona         1
#      Química              5
# 2012 Biologia             3
#      Ciências             4
#      Física               9
#      Interdisciplinar     4
#      Não menciona         2
#      Química              4
# 2014 Biologia             9
#      Física               3
#      Interdisciplinar     1
#      Química              8
# 2016 Ciências             4
#      Física               1
#      Não menciona         1
#      Química              2
# 2018 Biologia             4
#      Ciências             4
#      Não menciona         1
#      Química              1
