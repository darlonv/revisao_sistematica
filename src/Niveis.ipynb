# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
# %matplotlib inline

# %%
base = pd.read_csv('../bases/anos_e_niveis.csv')

# %%
base['Nível de Ensino'].unique()
# Out:
# array(['Graduação', 'Ensino Médio', 'Formação Continuada',
#        'Ensino Fundamental', 'Não menciona', 'Pós Graduação'],
#       dtype=object)

# %%
dimensoes = 15, 5

# %%
plt.figure(figsize=dimensoes)
sns.countplot(x = 'Nível de Ensino', data=base, hue='Ano')
plt.ylabel('Número de publicações')
# Out:
# Text(0, 0.5, 'Número de publicações')

# %%
base.groupby(['Nível de Ensino','Ano'])[['Ano']].count()
# Out:
#                           Ano
# Nível de Ensino     Ano
# Ensino Fundamental  2004    1
#                     2006    1
#                     2008    5
#                     2010    1
#                     2012    2
# Ensino Médio        2004    8
#                     2006    7
#                     2008    7
#                     2010    5
#                     2012    8
#                     2014    5
#                     2016    3
#                     2018    2
# Formação Continuada 2004    2
#                     2008    4
#                     2010    3
#                     2012    4
#                     2014    1
#                     2016    2
#                     2018    1
# Graduação           2004   12
#                     2006    5
#                     2008    7
#                     2010    8
#                     2012   10
#                     2014   11
#                     2016    1
#                     2018    5
# Não menciona        2004    2
#                     2008    2
#                     2014    2
#                     2016    1
#                     2018    1
# Pós Graduação       2006    1
#                     2008    1
#                     2010    3
#                     2012    2
#                     2014    2
#                     2016    1
#                     2018    1

# %%
plt.figure(figsize=dimensoes)
sns.countplot(x = 'Ano', data=base, hue='Nível de Ensino')
plt.ylabel('Número de publicações')
# Out:
# Text(0, 0.5, 'Número de publicações')

# %%
base.groupby(['Ano','Nível de Ensino'])[['Nível de Ensino']].count()
# Out:
#                           Nível de Ensino
# Ano  Nível de Ensino
# 2004 Ensino Fundamental                 1
#      Ensino Médio                       8
#      Formação Continuada                2
#      Graduação                         12
#      Não menciona                       2
# 2006 Ensino Fundamental                 1
#      Ensino Médio                       7
#      Graduação                          5
#      Pós Graduação                      1
# 2008 Ensino Fundamental                 5
#      Ensino Médio                       7
#      Formação Continuada                4
#      Graduação                          7
#      Não menciona                       2
#      Pós Graduação                      1
# 2010 Ensino Fundamental                 1
#      Ensino Médio                       5
#      Formação Continuada                3
#      Graduação                          8
#      Pós Graduação                      3
# 2012 Ensino Fundamental                 2
#      Ensino Médio                       8
#      Formação Continuada                4
#      Graduação                         10
#      Pós Graduação                      2
# 2014 Ensino Médio                       5
#      Formação Continuada                1
#      Graduação                         11
#      Não menciona                       2
#      Pós Graduação                      2
# 2016 Ensino Médio                       3
#      Formação Continuada                2
#      Graduação                          1
#      Não menciona                       1
#      Pós Graduação                      1
# 2018 Ensino Médio                       2
#      Formação Continuada                1
#      Graduação                          5
#      Não menciona                       1
#      Pós Graduação                      1
